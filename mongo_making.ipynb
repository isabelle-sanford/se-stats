# %%
import pandas as pd

# %%
from pymongo import MongoClient

CONNECTION_STRING = "mongodb://127.0.0.1:27017/isanford"
client = MongoClient(CONNECTION_STRING)
#client = MongoClient('localhost', 27017)

db = client["isanford"]

players = db["players"]
games = db["games"]

# %%
# probably unnecessary? idk. Could work as a last filtery step
alignment = pd.read_csv("data/keys/alignment.csv").reset_index().rename(columns={"index": "alignment_id"})
print(alignment.head())

setting = pd.read_csv("data/keys/setting.csv")
print(setting.head())

death = pd.read_csv("data/keys/death.csv").reset_index().rename(columns={"index": "death_id"})
death.head()

# %%
# IMPORTING DATA TAB
data = pd.read_csv("data/original_data/orig_data_040622.csv")

data.rename(inplace=True, columns={
    "ID": "pg_id",
    "Player": "player_name",
    "Alignment": "alignment_char",
    "Faction Outcome": "win", 
    "First Hit": "first_hit", 
    "Last Hit": "last_hit",
    "# of Hits": "num_hits",
    "Death/\r\n Survival": "death_char", # ??? sometimes \r\n sometimes \n
    "Inactive": "inactive",
    "Mod": "IM",
    "Game Type": "game_format",
    "Game #": "game_num",
    "Unnamed: 15": "game_string", # these depend on other cols. name in sheet pls
    "Role": "role",
    "Unnamed: 18": "secondary_role",
    "Main?": "main_gm"
    })

print(data.columns)

data = data[data["Spec"] != "Y"]

data = data.filter([
    "pg_id", 
    "player_name",
    "alignment_char",
    "win",
    "first_hit", "last_hit", "num_hits",
    "death_char",
    "inactive",
    "GM", "main_gm", "IM", # "Spec",
    "game_string", #"game_format", "game_num",
    "role", "secondary_role"
    ])

data.head()

# more cleaning here?
# Out:
# Index(['pg_id', 'player_name', 'alignment_char', 'win', 'first_hit',
#        'last_hit', 'num_hits', 'death_char', 'inactive', 'GM', 'main_gm', 'IM',
#        'Spec', 'game_format', 'game_num', 'game_string', 'Broken', 'role',
#        'secondary_role', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')
#    pg_id player_name alignment_char  win  first_hit  last_hit  num_hits  \
# 0      1        Meta            NaN  NaN        NaN       NaN       NaN
# 1      2    Cracknut              G    L        1.0       1.0       1.0
# 2      3  Edgedancer              G    L        2.0       2.0       1.0
# 3      4   Mailliw73              G    L        4.0       4.0       1.0
# 4      5      Aether              E    W        4.0       4.0       1.0
#
#   death_char inactive   GM main_gm   IM game_string     role  \
# 0        NaN      NaN    Y       Y  NaN         LG1       GM
# 1          E      NaN  NaN     NaN  NaN         LG1   Tineye
# 2          X      NaN  NaN     NaN  NaN         LG1      Cop
# 3          X      NaN  NaN     NaN  NaN         LG1  Regular
# 4          V      NaN  NaN     NaN  NaN         LG1   Smoker
#
#                         secondary_role
# 0  Roles that are unique and don't fit
# 1                MR1/LG8/MR7 need work
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN

# %%
data.tail()
# Out:
#       pg_id player_name alignment_char  win  first_hit  last_hit  num_hits  \
# 5890   5891   StrikerEZ            NaN  NaN        NaN       NaN       NaN
# 5891   5892        Bort            NaN  NaN        NaN       NaN       NaN
# 5892   5893          TJ            NaN  NaN        NaN       NaN       NaN
# 5893   5894  Ashbringer            NaN  NaN        NaN       NaN       NaN
# 5894   5895    Elbereth            NaN  NaN        NaN       NaN       NaN
#
#      death_char inactive   GM main_gm   IM game_string role secondary_role
# 5890        NaN      NaN  NaN     NaN  NaN        MR57  NaN            NaN
# 5891        NaN      NaN  NaN     NaN  NaN        MR57  NaN            NaN
# 5892        NaN      NaN  NaN     NaN  NaN        MR57  NaN            NaN
# 5893        NaN      NaN    Y       Y  NaN        LG84   GM            NaN
# 5894        NaN      NaN  NaN     NaN    Y        LG84   IM            NaN

# %%
# IMPORTING GAME TAB

# header = 1 because there's an extra header row on top w categories
game = pd.read_csv("data/original_data/orig_game_040622.csv", header=1)

game.reset_index(inplace=True)

game.columns
# Out:
# Index(['index', 'format', 'num', 'auto?', '# Players', '# Cycles', '# Posts',
#        'Fundamentals', 'Winner', 'Complexity', 'Role Madness', 'Anon', 'Mech',
#        'Dist', 'Broken', '# Elims', 'Elim %', '# Xed', '# Vig'd', '# Deaths',
#        '# Survivors', '# E killed', '# M killed', '# N killed', '# V killed',
#        '# FF', '# Xed.1', '# I killed', '# pinchhitters', '# Spectators',
#        'GM(s)', 'IM', 'Title/Link', 'Sanderson? ', 'World', 'start_date',
#        'end_date', 'link'],
#       dtype='object')

# %%
# ! Need to be careful about sheet renaming cols - some kind of check?
game.rename(inplace=True, columns={
    "index": "game_id",
    "format": "game_format",
    "num": "game_num", 
    "auto?": "game_string", # optional? 
    "# Players": "num_players", # optional
    "# Cycles": "num_cycles",
    "# Posts": "num_posts",
    "Fundamentals": "fundamentals", 
    "Role Madness": "role_madness",
    "Winner": "winner", # optional
    "Complexity": "complexity",
    #"Broken": "broken", # TODO make into mech/dist once that's set in sheet
    "Mech": "mechanics_balance", # blank rn!!
    "Dist": "distribution_balance",
    "World": "setting", # need to make setting table and replace this w setting_id
    "Anon": "anon_num", 
    "Title/Link": "title", # need to get link separately. hidden col? 
    # LINK
    "start_date": "start_date",
    "end_date": "end_date",
    "# Elims": "num_elims",
    "# Survivors": "num_survivors",
    "Sanderson?": "is_sanderson"
    })

print(game.columns)

# remaining columns are just calculated from data test
game = game.filter([
    "game_id",
    "game_format", "game_num", "game_string",
    "num_players",
    #"IM", # currently blank - pulling from Data instead
    "num_cycles", 
    "num_posts", 
    "fundamentals", "role_madness", "complexity", 
    "winner", 
    "mechanics_balance", "distribution_balance",
    #"broken", 
    "setting",
    "anon_num",
    "title",
    "start_date", "end_date",
    "num_elims",
    "num_survivors",
])


game.tail()
# check for almost all NaN rows! extra checkboxes cause this
# Out:
# Index(['game_id', 'game_format', 'game_num', 'game_string', 'num_players',
#        'num_cycles', 'num_posts', 'fundamentals', 'winner', 'complexity',
#        'role_madness', 'anon_num', 'mechanics_balance', 'distribution_balance',
#        'Broken', 'num_elims', 'Elim %', '# Xed', '# Vig'd', '# Deaths',
#        'num_survivors', '# E killed', '# M killed', '# N killed', '# V killed',
#        '# FF', '# Xed.1', '# I killed', '# pinchhitters', '# Spectators',
#        'GM(s)', 'IM', 'title', 'Sanderson? ', 'setting', 'start_date',
#        'end_date', 'link'],
#       dtype='object')
#      game_id game_format  game_num game_string  num_players num_cycles  \
# 208      208          LG      83.0        LG83         28.0          6
# 209      209          BT       1.0         BT1         12.0          4
# 210      210          QF      59.0        QF59         15.0          7
# 211      211          MR      57.0        MR57          NaN        NaN
# 212      212          LG      84.0        LG84          NaN        NaN
#
#      num_posts fundamentals role_madness     complexity winner  \
# 208        NaN          V/E        False            NaN      E
# 209        NaN          V/E        False            NaN      E
# 210        NaN          V/E        False            NaN      E
# 211        NaN          V/E        False  Semi Standard    NaN
# 212        NaN          NaN          NaN            NaN    NaN
#
#      mechanics_balance  distribution_balance        setting  anon_num  \
# 208                NaN                   NaN            NaN       NaN
# 209                NaN                   NaN  Cross-Cosmere       NaN
# 210                NaN                   NaN         Roshar       NaN
# 211                NaN                   NaN            NaN       NaN
# 212                NaN                   NaN            NaN       NaN
#
#                           title  start_date  end_date  num_elims  \
# 208                The Survivor         NaN       NaN        6.0
# 209          Auction of Stories         NaN       NaN        NaN
# 210  Bachelor - Roshar Edition!         NaN       NaN        NaN
# 211                         NaN         NaN       NaN        NaN
# 212                         NaN         NaN       NaN        NaN
#
#      num_survivors
# 208            7.0
# 209            NaN
# 210            NaN
# 211            NaN
# 212            NaN

# %%
games_db = {}

for full_row in game.iterrows():
    row = full_row[1]

    game_dict = {
        "_id": row["game_id"],
        "format": row["game_format"],
        "game_num": row["game_num"],
        "game_string": row["game_string"],

        "basics": {
            "fundamentals": row["fundamentals"],
            "complexity": row["complexity"],
            "role_madness": row["role_madness"]
        },

        "player_stats": {
            "num_players": row["num_players"],
            "num_elims": row["num_elims"],
            "num_survivors": row["num_survivors"],
            "player_list": []
        },

        "winner": row["winner"],
        
        "num_cycles": row["num_cycles"],
        "num_posts": row["num_posts"],
        "title": row["title"],

        "balance": {
            "mechanics": row["mechanics_balance"],
            "distribution": row["distribution_balance"]
        },

        "setting": { # idk
            "world": row["setting"]
            #"sanderson": row["is_sanderson"]
        },

        "GMs": []

        # want start and end date once present
    }

    if str(row["anon_num"]) != "nan": # gotta be a better way
        game_dict["anon_num"] = row["anon_num"]
    
    games_db[row["game_string"]] = game_dict


# still want: IM, GMs, playerlist (at least), is sanderson?

# %%
games_db["MR38.1"]
# Out:
# {'_id': 145,
#  'format': 'MR',
#  'game_num': 38.1,
#  'game_string': 'MR38.1',
#  'basics': {'fundamentals': 'U', 'complexity': 'Basic', 'role_madness': False},
#  'player_stats': {'num_players': 18.0,
#   'num_elims': 5.0,
#   'num_survivors': 15.0,
#   'player_list': []},
#  'winner': 'E',
#  'num_cycles': nan,
#  'num_posts': nan,
#  'title': 'The Council of Elrond',
#  'balance': {'mechanics': nan, 'distribution': nan},
#  'setting': {'world': 'Lord of the Rings'},
#  'GMs': []}

# %%
players_db = {}

# maybe make player ids

for full_row in data.iterrows():
    row = full_row[1]

    name = row["player_name"]
    if name not in players_db:
         
        player_dict = {
            "player_name": name,
            "games": [],
            # other stats? 
        }

        players_db[name] = player_dict
    
    p = players_db[name]

    # spectator check???

    if (row["GM"] == "Y"):
        if "GMed" not in p:
            p["GMed"] = []
        
        p["GMed"].append({
            "game_string": row["game_string"],
            "main": True if row["main_gm"] == "Y" else False,
            # get other stuff ... somehow? idk 
        })

        games_db[row["game_string"]]["GMs"].append(name)

        continue # ehhhh
    
    if (row["IM"] == "Y"):
        if "IMed" not in p:
            p["IMed"] = []
        
        p["IMed"].append({
            "game_string": row["game_string"]
            # ????
        })

        games_db[row["game_string"]]["IM"] = name

        continue
    
    p["games"].append({
        "game_string": row["game_string"],
        "alignment": row["alignment_char"],
        "death": row["death_char"],
        "result": row["win"],
        "hits": {
            "first": row["first_hit"],
            "last": row["last_hit"],
            "num": row["num_hits"]
        },
        "roles": [row["role"], row["secondary_role"]],
        "inactive": True if row["inactive"] == "Y" else False,
    })

    try:     
        games_db[row["game_string"]]["player_stats"]["player_list"].append(name)
    except:
        print(row)
        break

# %%
games_db["MR38.1"]
# why do I show up as GMing twice??
# Out:
# {'_id': 145,
#  'format': 'MR',
#  'game_num': 38.1,
#  'game_string': 'MR38.1',
#  'basics': {'fundamentals': 'U', 'complexity': 'Basic', 'role_madness': False},
#  'player_stats': {'num_players': 18.0,
#   'num_elims': 5.0,
#   'num_survivors': 15.0,
#   'player_list': ['Haelbarde',
#    'Straw',
#    'Fifth Scholar',
#    'Coda',
#    'Kasimir',
#    'Elandera',
#    'Amanuensis',
#    'xinoehp512',
#    'Wonko the Sane',
#    'Pejidot',
#    'Burnt Spaghetti',
#    'Aragorn',
#    'StrikerEZ',
#    'Madagascar',
#    'GoWibble',
#    'Rathmaskal',
#    'STINK',
#    'Young Bard',
#    'Haelbarde',
#    'Straw',
#    'Fifth Scholar',
#    'Coda',
#    'Kasimir',
#    'Elandera',
#    'Amanuensis',
#    'xinoehp512',
#    'Wonko the Sane',
#    'Pejidot',
#    'Burnt Spaghetti',
#    'Aragorn',
#    'StrikerEZ',
#    'Madagascar',
#    'GoWibble',
#    'Rathmaskal',
#    'STINK',
#    'Young Bard']},
#  'winner': 'E',
#  'num_cycles': nan,
#  'num_posts': nan,
#  'title': 'The Council of Elrond',
#  'balance': {'mechanics': nan, 'distribution': nan},
#  'setting': {'world': 'Lord of the Rings'},
#  'GMs': ['Elbereth', 'Elbereth'],
#  'IM': 'little wilson'}

# %%
players_db["Elbereth"]
# Out:
# {'player_name': 'Elbereth',
#  'games': [{'game_string': 'LG15.1',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'L',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG15.2',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': ['Kill', nan],
#    'inactive': False},
#   {'game_string': 'MR10',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'L',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'AG2',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'L',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'QF12',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'L',
#    'hits': {'first': nan, 'last': nan, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG16',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'MR11',
#    'alignment': 'E',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': nan},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG17',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'QF13',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': nan},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG18',
#    'alignment': 'G',
#    'death': 'O',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'MR12',
#    'alignment': 'F',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': nan},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'QF14',
#    'alignment': 'G',
#    'death': 'N',
#    'result': 'D',
#    'hits': {'first': 6.0, 'last': 12.0, 'num': 2.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG20',
#    'alignment': 'N',
#    'death': 'N',
#    'result': 'L',
#    'hits': {'first': 6.0, 'last': 6.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'QF15',
#    'alignment': 'E',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': nan},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG21',
#    'alignment': 'N',
#    'death': 'N',
#    'result': 'L',
#    'hits': {'first': 1.0, 'last': 1.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG22',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': nan},
#    'roles': ['Kill', nan],
#    'inactive': False},
#   {'game_string': 'QF16',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'W',
#    'hits': {'first': 4.0, 'last': 4.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG23',
#    'alignment': 'C',
#    'death': 'X',
#    'result': 'W',
#    'hits': {'first': 6.0, 'last': 6.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'MR15',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': nan},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG24',
#    'alignment': 'G',
#    'death': 'N',
#    'result': 'L',
#    'hits': {'first': 3.0, 'last': 3.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'QF17',
#    'alignment': 'N',
#    'death': 'N',
#    'result': 'L',
#    'hits': {'first': 1.0, 'last': 1.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'MR16',
#    'alignment': 'F',
#    'death': 'N',
#    'result': 'W',
#    'hits': {'first': 9.0, 'last': 9.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'MR17',
#    'alignment': 'G',
#    'death': 'M',
#    'result': 'L',
#    'hits': {'first': 3.0, 'last': 3.0, 'num': 2.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG27',
#    'alignment': 'F',
#    'death': 'S',
#    'result': 'D',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'QF19',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'W',
#    'hits': {'first': 1.0, 'last': 1.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG28',
#    'alignment': 'E',
#    'death': 'S',
#    'result': 'L',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'MR18',
#    'alignment': 'G',
#    'death': 'X',
#    'result': 'L',
#    'hits': {'first': 1.0, 'last': 1.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'AG3',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'L',
#    'hits': {'first': 13.0, 'last': 13.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG30',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'L',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'QF22',
#    'alignment': 'G',
#    'death': 'X',
#    'result': 'L',
#    'hits': {'first': 2.0, 'last': 2.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'QF23',
#    'alignment': 'E',
#    'death': 'X',
#    'result': 'W',
#    'hits': {'first': 6.0, 'last': 6.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG35',
#    'alignment': 'N',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'MR23',
#    'alignment': 'F',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': 4.0, 'last': 5.0, 'num': 2.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG37',
#    'alignment': 'N',
#    'death': 'S',
#    'result': 'D',
#    'hits': {'first': nan, 'last': nan, 'num': nan},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG39',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'L',
#    'hits': {'first': 9.0, 'last': 9.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG43',
#    'alignment': 'C',
#    'death': 'S',
#    'result': 'L',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG46',
#    'alignment': 'N',
#    'death': 'I',
#    'result': 'L',
#    'hits': {'first': 2.0, 'last': 9.0, 'num': 2.0},
#    'roles': [nan, nan],
#    'inactive': True},
#   {'game_string': 'QF39',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'L',
#    'hits': {'first': 3.0, 'last': 3.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG60',
#    'alignment': 'G',
#    'death': 'X',
#    'result': 'L',
#    'hits': {'first': 6.0, 'last': 8.0, 'num': 3.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'QF40.1',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'L',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'QF40.2',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'L',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG61',
#    'alignment': 'G',
#    'death': 'X',
#    'result': 'W',
#    'hits': {'first': 4.0, 'last': 4.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG62',
#    'alignment': 'F',
#    'death': 'O',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'QF44',
#    'alignment': 'E',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG67',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'L',
#    'hits': {'first': 4.0, 'last': 4.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': True},
#   {'game_string': 'MR43',
#    'alignment': 'G',
#    'death': 'I',
#    'result': 'L',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': True}],
#  'GMed': [{'game_string': 'QF11', 'main': False},
#   {'game_string': 'LG19', 'main': True},
#   {'game_string': 'MR13', 'main': True},
#   {'game_string': 'MR14', 'main': True},
#   {'game_string': 'LG25', 'main': True},
#   {'game_string': 'LG26', 'main': True},
#   {'game_string': 'QF18', 'main': True},
#   {'game_string': 'LG29', 'main': False},
#   {'game_string': 'LG31', 'main': True},
#   {'game_string': 'LG33', 'main': True},
#   {'game_string': 'QF25', 'main': True},
#   {'game_string': 'AG4', 'main': False},
#   {'game_string': 'LG42', 'main': False},
#   {'game_string': 'LG44', 'main': False},
#   {'game_string': 'LG49', 'main': True},
#   {'game_string': 'MR38.1', 'main': True},
#   {'game_string': 'MR38.2', 'main': True},
#   {'game_string': 'AG6', 'main': True},
#   {'game_string': 'LG64', 'main': True},
#   {'game_string': 'LG65', 'main': True},
#   {'game_string': 'QF46', 'main': True},
#   {'game_string': 'AG7', 'main': True},
#   {'game_string': 'AG8', 'main': True},
#   {'game_string': 'BT1', 'main': True}],
#  'IMed': [{'game_string': 'MR42'},
#   {'game_string': 'LG68'},
#   {'game_string': 'LG70'},
#   {'game_string': 'QF48'},
#   {'game_string': 'LG72'},
#   {'game_string': 'MR50'},
#   {'game_string': 'LG77'},
#   {'game_string': 'LG84'}]}

# %%
resP = players.insert_many(players_db.values())

resP

# %%
resG = games.insert_many(games_db.values())

resG

# %% [markdown]
# # indices
#
# db.players.createindex({"player_name": 1})
#
# db.games.createindex({"game_format": 1})

# %%
resP.inserted_ids
# Out:
# [ObjectId('624e5632d20eaa6182dc3889'),
#  ObjectId('624e5632d20eaa6182dc388a'),
#  ObjectId('624e5632d20eaa6182dc388b'),
#  ObjectId('624e5632d20eaa6182dc388c'),
#  ObjectId('624e5632d20eaa6182dc388d'),
#  ObjectId('624e5632d20eaa6182dc388e'),
#  ObjectId('624e5632d20eaa6182dc388f'),
#  ObjectId('624e5632d20eaa6182dc3890'),
#  ObjectId('624e5632d20eaa6182dc3891'),
#  ObjectId('624e5632d20eaa6182dc3892'),
#  ObjectId('624e5632d20eaa6182dc3893'),
#  ObjectId('624e5632d20eaa6182dc3894'),
#  ObjectId('624e5632d20eaa6182dc3895'),
#  ObjectId('624e5632d20eaa6182dc3896'),
#  ObjectId('624e5632d20eaa6182dc3897'),
#  ObjectId('624e5632d20eaa6182dc3898'),
#  ObjectId('624e5632d20eaa6182dc3899'),
#  ObjectId('624e5632d20eaa6182dc389a'),
#  ObjectId('624e5632d20eaa6182dc389b'),
#  ObjectId('624e5632d20eaa6182dc389c'),
#  ObjectId('624e5632d20eaa6182dc389d'),
#  ObjectId('624e5632d20eaa6182dc389e'),
#  ObjectId('624e5632d20eaa6182dc389f'),
#  ObjectId('624e5632d20eaa6182dc38a0'),
#  ObjectId('624e5632d20eaa6182dc38a1'),
#  ObjectId('624e5632d20eaa6182dc38a2'),
#  ObjectId('624e5632d20eaa6182dc38a3'),
