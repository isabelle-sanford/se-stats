# %%
import pandas as pd

# %%
from pymongo import MongoClient

CONNECTION_STRING = "mongodb://127.0.0.1:27017/isanford"
client = MongoClient(CONNECTION_STRING)
#client = MongoClient('localhost', 27017)

db = client["isanford"]

players = db["players"]
games = db["games"]

# %%
# probably unnecessary? idk. Could work as a last filtery step
alignment = pd.read_csv("data/keys/alignment.csv").reset_index().rename(columns={"index": "alignment_id"})
print(alignment.head())

setting = pd.read_csv("data/keys/setting.csv")
print(setting.head())

death = pd.read_csv("data/keys/death.csv").reset_index().rename(columns={"index": "death_id"})
death.head()

# %%
# IMPORTING DATA TAB
data = pd.read_csv("data/original_data/orig_data_040622.csv")

data.rename(inplace=True, columns={
    "ID": "pg_id",
    "Player": "player_name",
    "Alignment": "alignment_char",
    "Faction Outcome": "win", 
    "First Hit": "first_hit", 
    "Last Hit": "last_hit",
    "# of Hits": "num_hits",
    "Death/\r\n Survival": "death_char", # ??? sometimes \r\n sometimes \n
    "Inactive": "inactive",
    "Mod": "IM",
    "Game Type": "game_format",
    "Game #": "game_num",
    "Unnamed: 15": "game_string", # these depend on other cols. name in sheet pls
    "Role": "role",
    "Unnamed: 18": "secondary_role",
    "Main?": "main_gm"
    })

print(data.columns)

data = data[data["Spec"] != "Y"]

data = data.filter([
    "pg_id", 
    "player_name",
    "alignment_char",
    "win",
    "first_hit", "last_hit", "num_hits",
    "death_char",
    "inactive",
    "GM", "main_gm", "IM", # "Spec",
    "game_string", #"game_format", "game_num",
    "role", "secondary_role"
    ])

data.head()

# more cleaning here?
# Out:
# Index(['pg_id', 'player_name', 'alignment_char', 'win', 'first_hit',
#        'last_hit', 'num_hits', 'death_char', 'inactive', 'GM', 'main_gm', 'IM',
#        'Spec', 'game_format', 'game_num', 'game_string', 'Broken', 'role',
#        'secondary_role', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')
#    pg_id player_name alignment_char  win  first_hit  last_hit  num_hits  \
# 0      1        Meta            NaN  NaN        NaN       NaN       NaN
# 1      2    Cracknut              G    L        1.0       1.0       1.0
# 2      3  Edgedancer              G    L        2.0       2.0       1.0
# 3      4   Mailliw73              G    L        4.0       4.0       1.0
# 4      5      Aether              E    W        4.0       4.0       1.0
#
#   death_char inactive   GM main_gm   IM game_string     role  \
# 0        NaN      NaN    Y       Y  NaN         LG1       GM
# 1          E      NaN  NaN     NaN  NaN         LG1   Tineye
# 2          X      NaN  NaN     NaN  NaN         LG1      Cop
# 3          X      NaN  NaN     NaN  NaN         LG1  Regular
# 4          V      NaN  NaN     NaN  NaN         LG1   Smoker
#
#                         secondary_role
# 0  Roles that are unique and don't fit
# 1                MR1/LG8/MR7 need work
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN

# %%
data.tail()
# Out:
#       pg_id player_name alignment_char  win  first_hit  last_hit  num_hits  \
# 5890   5891   StrikerEZ            NaN  NaN        NaN       NaN       NaN
# 5891   5892        Bort            NaN  NaN        NaN       NaN       NaN
# 5892   5893          TJ            NaN  NaN        NaN       NaN       NaN
# 5893   5894  Ashbringer            NaN  NaN        NaN       NaN       NaN
# 5894   5895    Elbereth            NaN  NaN        NaN       NaN       NaN
#
#      inactive   GM main_gm   IM game_string role secondary_role
# 5890      NaN  NaN     NaN  NaN        MR57  NaN            NaN
# 5891      NaN  NaN     NaN  NaN        MR57  NaN            NaN
# 5892      NaN  NaN     NaN  NaN        MR57  NaN            NaN
# 5893      NaN    Y       Y  NaN        LG84   GM            NaN
# 5894      NaN  NaN     NaN    Y        LG84   IM            NaN

# %%
# IMPORTING GAME TAB

# header = 1 because there's an extra header row on top w categories
game = pd.read_csv("data/original_data/orig_game_040622.csv", header=1)

# cols wanted: id, format, number, string, anon num,
# mech balance, dist balance, IM id, start date, end date
# num cycles, num posts, setting id
# complexity, fundamentals, role madness

# cols still needed: mech balance, dist balance, 
# start date, end date

game.reset_index(inplace=True)

game.columns
# Out:
# Index(['index', 'format', 'num', 'auto?', '# Players', '# Cycles', '# Posts',
#        'Fundamentals', 'Winner', 'Complexity', 'Role Madness', 'Anon', 'Mech',
#        'Dist', 'Broken', '# Elims', 'Elim %', '# Xed', '# Vig'd', '# Deaths',
#        '# Survivors', '# E killed', '# M killed', '# N killed', '# V killed',
#        '# FF', '# Xed.1', '# I killed', '# pinchhitters', '# Spectators',
#        'GM(s)', 'IM', 'Title/Link', 'Sanderson? ', 'World', 'start_date',
#        'end_date', 'link'],
#       dtype='object')

# %%
# ! Need to be careful about sheet renaming cols - some kind of check?
game.rename(inplace=True, columns={
    "index": "game_id",
    "format": "game_format",
    "num": "game_num", 
    "auto?": "game_string", # optional? 
    "# Players": "num_players", # optional
    "# Cycles": "num_cycles",
    "# Posts": "num_posts",
    "Fundamentals": "fundamentals", 
    "Role Madness": "role_madness",
    "Winner": "winner", # optional
    "Complexity": "complexity",
    #"Broken": "broken", # TODO make into mech/dist once that's set in sheet
    "Mech": "mechanics_balance", # blank rn!!
    "Dist": "distribution_balance",
    "World": "setting", # need to make setting table and replace this w setting_id
    "Anon": "anon_num", 
    "Title/Link": "title", # need to get link separately. hidden col? 
    # LINK
    "start_date": "start_date",
    "end_date": "end_date",
    "# Elims": "num_elims",
    "# Survivors": "num_survivors",
    "Sanderson?": "is_sanderson"
    })

print(game.columns)

# remaining columns are just calculated from data test
game = game.filter([
    "game_id",
    "game_format", "game_num", "game_string",
    "num_players",
    #"IM", # currently blank - pulling from Data instead
    "num_cycles", 
    "num_posts", 
    "fundamentals", "role_madness", "complexity", 
    "winner", 
    "mechanics_balance", "distribution_balance",
    #"broken", 
    "setting",
    "anon_num",
    "title",
    "start_date", "end_date",
    "num_elims",
    "num_survivors",
])


game.tail()
# check for almost all NaN rows! extra checkboxes cause this
# Out:
# Index(['game_id', 'game_format', 'game_num', 'game_string', 'num_players',
#        'num_cycles', 'num_posts', 'fundamentals', 'winner', 'complexity',
#        'role_madness', 'anon_num', 'mechanics_balance', 'distribution_balance',
#        'Broken', 'num_elims', 'Elim %', '# Xed', '# Vig'd', '# Deaths',
#        'num_survivors', '# E killed', '# M killed', '# N killed', '# V killed',
#        '# FF', '# Xed.1', '# I killed', '# pinchhitters', '# Spectators',
#        'GM(s)', 'IM', 'title', 'Sanderson? ', 'setting', 'start_date',
#        'end_date', 'link'],
#       dtype='object')
#      game_id game_format  game_num game_string  num_players num_cycles  \
# 208      208          LG      83.0        LG83         28.0          6
# 209      209          BT       1.0         BT1         12.0          4
# 210      210          QF      59.0        QF59         15.0          7
# 211      211          MR      57.0        MR57          NaN        NaN
# 212      212          LG      84.0        LG84          NaN        NaN
#
#      num_posts fundamentals role_madness     complexity winner  \
# 208        NaN          V/E        False            NaN      E
# 209        NaN          V/E        False            NaN      E
# 210        NaN          V/E        False            NaN      E
# 211        NaN          V/E        False  Semi Standard    NaN
# 212        NaN          NaN          NaN            NaN    NaN
#
#      mechanics_balance  distribution_balance        setting  anon_num  \
# 208                NaN                   NaN            NaN       NaN
# 209                NaN                   NaN  Cross-Cosmere       NaN
# 210                NaN                   NaN         Roshar       NaN
# 211                NaN                   NaN            NaN       NaN
# 212                NaN                   NaN            NaN       NaN
#
#                           title  start_date  end_date  num_elims  \
# 208                The Survivor         NaN       NaN        6.0
# 209          Auction of Stories         NaN       NaN        NaN
# 210  Bachelor - Roshar Edition!         NaN       NaN        NaN
# 211                         NaN         NaN       NaN        NaN
# 212                         NaN         NaN       NaN        NaN
#
#      num_survivors
# 208            7.0
# 209            NaN
# 210            NaN
# 211            NaN
# 212            NaN

# %%
games_db = {}

for full_row in game.iterrows():
    row = full_row[1]

    game_dict = {
        "_id": row["game_id"],
        "format": row["game_format"],
        "game_num": row["game_num"],
        "game_string": row["game_string"],

        "basics": {
            "fundamentals": row["fundamentals"],
            "complexity": row["complexity"],
            "role_madness": row["role_madness"]
        },

        "player_stats": {
            "num_players": row["num_players"],
            "num_elims": row["num_elims"],
            "num_survivors": row["num_survivors"],
            "player_list": []
        },

        "winner": row["winner"],
        
        "num_cycles": row["num_cycles"],
        "num_posts": row["num_posts"],
        "title": row["title"],

        "balance": {
            "mechanics": row["mechanics_balance"],
            "distribution": row["distribution_balance"]
        },

        "setting": { # idk
            "world": row["setting"]
            #"sanderson": row["is_sanderson"]
        },

        "GMs": []

        # want start and end date once present
    }

    if str(row["anon_num"]) != "nan": # gotta be a better way
        game_dict["anon_num"] = row["anon_num"]
    
    games_db[row["game_string"]] = game_dict


# still want: IM, GMs, playerlist (at least), is sanderson?

# %%
games_db["MR38.1"]
# Out:
# {'_id': 145,
#  'format': 'MR',
#  'game_num': 38.1,
#  'game_string': 'MR38.1',
#  'basics': {'fundamentals': 'U', 'complexity': 'Basic', 'role_madness': False},
#  'player_stats': {'num_players': 18.0,
#   'num_elims': 5.0,
#   'num_survivors': 15.0,
#   'player_list': []},
#  'winner': 'E',
#  'num_cycles': nan,
#  'num_posts': nan,
#  'title': 'The Council of Elrond',
#  'balance': {'mechanics': nan, 'distribution': nan},
#  'setting': {'world': 'Lord of the Rings'},
#  'GMs': []}

# %%
players_db = {}

for full_row in data.iterrows():
    row = full_row[1]

    name = row["player_name"]
    if name not in players_db:
         
        player_dict = {
            "player_name": name,
            "games": [],
            # other stats? 
        }

        players_db[name] = player_dict
    
    p = players_db[name]

    # spectator check???

    if (row["GM"] == "Y"):
        if "GMed" not in p:
            p["GMed"] = []
        
        p["GMed"].append({
            "game_string": row["game_string"],
            "main": True if row["main_gm"] == "Y" else False,
            # get other stuff ... somehow? idk 
        })

        games_db[row["game_string"]]["GMs"].append(name)

        continue # ehhhh
    
    if (row["IM"] == "Y"):
        if "IMed" not in p:
            p["IMed"] = []
        
        p["IMed"].append({
            "game_string": row["game_string"]
            # ????
        })

        games_db[row["game_string"]]["IM"] = name

        continue
    
    p["games"].append({
        "game_string": row["game_string"],
        "alignment": row["alignment_char"],
        "death": row["death_char"],
        "result": row["win"],
        "hits": {
            "first": row["first_hit"],
            "last": row["last_hit"],
            "num": row["num_hits"]
        },
        "roles": [row["role"], row["secondary_role"]],
        "inactive": True if row["inactive"] == "Y" else False,
    })

    try:     
        games_db[row["game_string"]]["player_stats"]["player_list"].append(name)
    except:
        print(row)
        break

# %%
games_db["MR7"]
# Out:
# {'_id': 27,
#  'format': 'MR',
#  'game_num': 7.0,
#  'game_string': 'MR7',
#  'basics': {'fundamentals': 'FAC',
#   'complexity': 'Faction/FFA',
#   'role_madness': False},
#  'player_stats': {'num_players': 27.0,
#   'num_elims': 4.0,
#   'num_survivors': 10.0,
#   'player_list': ['Mailliw73',
#    'little wilson',
#    'Alvron',
#    'Aonar',
#    'Herowannabe',
#    'A Joe in the Bush',
#    'Wyrmhero',
#    'Jain',
#    'Araris Valerian',
#    'Seonid',
#    'dowanx',
#    'Bort',
#    'Kipper',
#    'Clanky',
#    'Phattemer',
#    'neodymium',
#    'Haelbarde',
#    'Emerald101',
#    'Orlok Tsubodai',
#    'Zas',
#    'LadyEowyn/Emilylime',
#    'Shallan',
#    'Bridge Boy/Elithanathile',
#    'Adamir',
#    'Paranoid King',
#    'Zephrer',
#    'Pixie']},
#  'winner': 'V',
#  'num_cycles': '12?',
#  'num_posts': 665.0,
#  'title': 'Eighty Splendid Suns',
#  'balance': {'mechanics': nan, 'distribution': nan},
#  'setting': {'world': 'Sel'},
#  'GMs': ['Kasimir'],
#  'IM': 'Gamma'}

# %%
players_db["Kasimir"]
# Out:
# {'player_name': 'Kasimir',
#  'games': [{'game_string': 'LG5',
#    'alignment': 'E',
#    'death': 'X',
#    'result': 'L',
#    'hits': {'first': 6.0, 'last': 6.0, 'num': 1.0},
#    'roles': ['Regular', nan],
#    'inactive': False},
#   {'game_string': 'MR1',
#    'alignment': 'F',
#    'death': 'X',
#    'result': 'L',
#    'hits': {'first': 2.0, 'last': 3.0, 'num': 4.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG6',
#    'alignment': 'D',
#    'death': 'E',
#    'result': 'L',
#    'hits': {'first': 2.0, 'last': 2.0, 'num': 1.0},
#    'roles': ['Conversion', nan],
#    'inactive': False},
#   {'game_string': 'QF2',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'L',
#    'hits': {'first': 3.0, 'last': 3.0, 'num': 1.0},
#    'roles': ['Regular', 'Jack of All Trades'],
#    'inactive': False},
#   {'game_string': 'LG7',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'W',
#    'hits': {'first': 5.0, 'last': 6.0, 'num': 2.0},
#    'roles': ['Protect', nan],
#    'inactive': False},
#   {'game_string': 'QF3',
#    'alignment': 'G',
#    'death': 'X',
#    'result': 'W',
#    'hits': {'first': 2.0, 'last': 2.0, 'num': 1.0},
#    'roles': ['Regular', nan],
#    'inactive': False},
#   {'game_string': 'MR3',
#    'alignment': 'E',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': ['Regular', nan],
#    'inactive': False},
#   {'game_string': 'MR4',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': 2.0, 'last': nan, 'num': 2.0},
#    'roles': ['Jester', nan],
#    'inactive': False},
#   {'game_string': 'AG1',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'L',
#    'hits': {'first': 2.0, 'last': 2.0, 'num': 1.0},
#    'roles': ['Regular', nan],
#    'inactive': False},
#   {'game_string': 'QF6',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'W',
#    'hits': {'first': 7.0, 'last': 7.0, 'num': 1.0},
#    'roles': ['Writeup Messages', nan],
#    'inactive': False},
#   {'game_string': 'LG12',
#    'alignment': 'N',
#    'death': 'N',
#    'result': 'L',
#    'hits': {'first': 9.0, 'last': 9.0, 'num': 1.0},
#    'roles': ['Matchmaker', nan],
#    'inactive': False},
#   {'game_string': 'MR9',
#    'alignment': 'E',
#    'death': 'I',
#    'result': 'L',
#    'hits': {'first': nan, 'last': nan, 'num': nan},
#    'roles': ['Redirect', nan],
#    'inactive': True},
#   {'game_string': 'LG15.2',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'W',
#    'hits': {'first': 1.0, 'last': 1.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'AG2',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'L',
#    'hits': {'first': 4.0, 'last': 4.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG20',
#    'alignment': 'E',
#    'death': 'O',
#    'result': 'L',
#    'hits': {'first': nan, 'last': 7.0, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': True},
#   {'game_string': 'QF20',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'L',
#    'hits': {'first': 3.0, 'last': 3.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG29',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'L',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'QF29',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'L',
#    'hits': {'first': 3.0, 'last': 3.0, 'num': 2.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'MR37',
#    'alignment': 'G',
#    'death': 'X',
#    'result': 'L',
#    'hits': {'first': 1.0, 'last': 1.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'MR38.1',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'L',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': ['Regular', nan],
#    'inactive': False},
#   {'game_string': 'MR38.2',
#    'alignment': 'G',
#    'death': 'X',
#    'result': 'W',
#    'hits': {'first': 4.0, 'last': 4.0, 'num': 1.0},
#    'roles': ['Regular', nan],
#    'inactive': False},
#   {'game_string': 'QF46',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'W',
#    'hits': {'first': 4.0, 'last': 4.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG68',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'AG7',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': ['Poisoner', nan],
#    'inactive': False},
#   {'game_string': 'LG73',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'W',
#    'hits': {'first': 7.0, 'last': 7.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG78',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'L',
#    'hits': {'first': 1.0, 'last': 1.0, 'num': 1.0},
#    'roles': ['Inventor', nan],
#    'inactive': False},
#   {'game_string': 'LG79',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'W',
#    'hits': {'first': 7.0, 'last': 7.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'LG80',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'W',
#    'hits': {'first': 2.0, 'last': 2.0, 'num': 1.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'MR52',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': ['Lynch Protect', nan],
#    'inactive': False},
#   {'game_string': 'MR53',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'L',
#    'hits': {'first': 1.0, 'last': 5.0, 'num': 2.0},
#    'roles': ['Double Life', nan],
#    'inactive': False},
#   {'game_string': 'LG82',
#    'alignment': 'G',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': ['Double Life', nan],
#    'inactive': False},
#   {'game_string': 'AG8',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'W',
#    'hits': {'first': 5.0, 'last': 6.0, 'num': 2.0},
#    'roles': ['Tineye', nan],
#    'inactive': False},
#   {'game_string': 'MR56',
#    'alignment': 'G',
#    'death': 'E',
#    'result': 'L',
#    'hits': {'first': 3.0, 'last': 3.0, 'num': 1.0},
#    'roles': ['Vote Change', nan],
#    'inactive': False},
#   {'game_string': 'LG83',
#    'alignment': 'N',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': ['Thief', nan],
#    'inactive': False},
#   {'game_string': 'BT1',
#    'alignment': 'E',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False},
#   {'game_string': 'QF59',
#    'alignment': 'E',
#    'death': 'S',
#    'result': 'W',
#    'hits': {'first': nan, 'last': nan, 'num': 0.0},
#    'roles': [nan, nan],
#    'inactive': False}],
#  'GMed': [{'game_string': 'MR7', 'main': True},
#   {'game_string': 'MR10', 'main': True},
#   {'game_string': 'LG28', 'main': True},
#   {'game_string': 'QF40.1', 'main': True},
#   {'game_string': 'QF40.2', 'main': True},
#   {'game_string': 'MR43', 'main': True},
#   {'game_string': 'LG74', 'main': True},
#   {'game_string': 'MR51', 'main': True},
#   {'game_string': 'QF54', 'main': True},
#   {'game_string': 'MR57', 'main': True}]}

# %%
resP = players.insert_many(players_db.values())

resP

# %%
resG = games.insert_many(games_db.values())

resG
